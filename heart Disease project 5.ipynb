# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("heart disease.csv")
df.head()
# Out:
#    63  1  4  140  260  0  1.1  112 1.2     3  2  ? ?.1  2.1
# 0  44  1  4  130  209  0    1  127   0     0  ?  ?   ?    0
# 1  60  1  4  132  218  0    1  140   1   1.5  3  ?   ?    2
# 2  55  1  4  142  228  0    1  149   1   2.5  1  ?   ?    1
# 3  66  1  3  110  213  1    2   99   1   1.3  2  ?   ?    0
# 4  66  1  3  120    0  0    1  120   0  -0.5  1  ?   ?    0

# %%
# As we can see no columns names let's add columns names to the data

# %%
df.columns=['age', 'sex', 'chest_pain_type', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num']

# %%
df
# Out:
#      age  sex  chest_pain_type trestbps chol fbs  restecg thalach exang  \
# 0     44    1                4      130  209   0        1     127     0
# 1     60    1                4      132  218   0        1     140     1
# 2     55    1                4      142  228   0        1     149     1
# 3     66    1                3      110  213   1        2      99     1
# 4     66    1                3      120    0   0        1     120     0
# ..   ...  ...              ...      ...  ...  ..      ...     ...   ...
# 194   54    0                4      127  333   1        1     154     0
# 195   62    1                1        ?  139   0        1       ?     ?
# 196   55    1                4      122  223   1        1     100     0
# 197   58    1                4        ?  385   1        2       ?     ?
# 198   62    1                2      120  254   0        2      93     1
#
#     oldpeak slope ca thal  num
# 0         0     ?  ?    ?    0
# 1       1.5     3  ?    ?    2
# 2       2.5     1  ?    ?    1
# 3       1.3     2  ?    ?    0
# 4      -0.5     1  ?    ?    0
# ..      ...   ... ..  ...  ...
# 194       0     ?  ?    ?    1
# 195       ?     ?  ?    ?    0
# 196       0     ?  ?    6    2
# 197       ?     ?  ?    ?    0
# 198       0     ?  ?    ?    1
#
# [199 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              199 non-null    int64
#  1   sex              199 non-null    int64
#  2   chest_pain_type  199 non-null    int64
#  3   trestbps         199 non-null    object
#  4   chol             199 non-null    object
#  5   fbs              199 non-null    object
#  6   restecg          199 non-null    int64
#  7   thalach          199 non-null    object
#  8   exang            199 non-null    object
#  9   oldpeak          199 non-null    object
#  10  slope            199 non-null    object
#  11  ca               199 non-null    object
#  12  thal             199 non-null    object
#  13  num              199 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 21.9+ KB

# %%
df.isnull().sum()
# Out:
# age                0
# sex                0
# chest_pain_type    0
# trestbps           0
# chol               0
# fbs                0
# restecg            0
# thalach            0
# exang              0
# oldpeak            0
# slope              0
# ca                 0
# thal               0
# num                0
# dtype: int64

# %%
#but as we can see there are'?' present in the dataset
df=df.replace('?',np.nan)

# %%
df
# Out:
#      age  sex  chest_pain_type trestbps chol fbs  restecg thalach exang  \
# 0     44    1                4      130  209   0        1     127     0
# 1     60    1                4      132  218   0        1     140     1
# 2     55    1                4      142  228   0        1     149     1
# 3     66    1                3      110  213   1        2      99     1
# 4     66    1                3      120    0   0        1     120     0
# ..   ...  ...              ...      ...  ...  ..      ...     ...   ...
# 194   54    0                4      127  333   1        1     154     0
# 195   62    1                1      NaN  139   0        1     NaN   NaN
# 196   55    1                4      122  223   1        1     100     0
# 197   58    1                4      NaN  385   1        2     NaN   NaN
# 198   62    1                2      120  254   0        2      93     1
#
#     oldpeak slope   ca thal  num
# 0         0   NaN  NaN  NaN    0
# 1       1.5     3  NaN  NaN    2
# 2       2.5     1  NaN  NaN    1
# 3       1.3     2  NaN  NaN    0
# 4      -0.5     1  NaN  NaN    0
# ..      ...   ...  ...  ...  ...
# 194       0   NaN  NaN  NaN    1
# 195     NaN   NaN  NaN  NaN    0
# 196       0   NaN  NaN    6    2
# 197     NaN   NaN  NaN  NaN    0
# 198       0   NaN  NaN  NaN    1
#
# [199 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# age                  0
# sex                  0
# chest_pain_type      0
# trestbps            56
# chol                 7
# fbs                  7
# restecg              0
# thalach             53
# exang               53
# oldpeak             56
# slope              102
# ca                 197
# thal               165
# num                  0
# dtype: int64

# %%
df.shape
# Out:
# (199, 14)

# %% [markdown]
# as we can see 199 rows present and columns like slope ca and thal are missing major value throughout so lets drop this columns.

# %%
df.drop(["slope","ca","thal"],inplace=True,axis=1)

# %%
df
# Out:
#      age  sex  chest_pain_type trestbps chol fbs  restecg thalach exang  \
# 0     44    1                4      130  209   0        1     127     0
# 1     60    1                4      132  218   0        1     140     1
# 2     55    1                4      142  228   0        1     149     1
# 3     66    1                3      110  213   1        2      99     1
# 4     66    1                3      120    0   0        1     120     0
# ..   ...  ...              ...      ...  ...  ..      ...     ...   ...
# 194   54    0                4      127  333   1        1     154     0
# 195   62    1                1      NaN  139   0        1     NaN   NaN
# 196   55    1                4      122  223   1        1     100     0
# 197   58    1                4      NaN  385   1        2     NaN   NaN
# 198   62    1                2      120  254   0        2      93     1
#
#     oldpeak  num
# 0         0    0
# 1       1.5    2
# 2       2.5    1
# 3       1.3    0
# 4      -0.5    0
# ..      ...  ...
# 194       0    1
# 195     NaN    0
# 196       0    2
# 197     NaN    0
# 198       0    1
#
# [199 rows x 11 columns]

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer(strategy="mean")

# %%
df["trestbps"]=si.fit_transform(df["trestbps"].values.reshape(-1,1))
df["chol"]=si.fit_transform(df["chol"].values.reshape(-1,1))
df["thalach"]=si.fit_transform(df["thalach"].values.reshape(-1,1))
df["exang"]=si.fit_transform(df["exang"].values.reshape(-1,1))
df["oldpeak"]=si.fit_transform(df["oldpeak"].values.reshape(-1,1))
df["fbs"]=si.fit_transform(df["fbs"].values.reshape(-1,1))

# %%
df
# Out:
#      age  sex  chest_pain_type   trestbps   chol  fbs  restecg     thalach  \
# 0     44    1                4  130.00000  209.0  0.0        1  127.000000
# 1     60    1                4  132.00000  218.0  0.0        1  140.000000
# 2     55    1                4  142.00000  228.0  0.0        1  149.000000
# 3     66    1                3  110.00000  213.0  1.0        2   99.000000
# 4     66    1                3  120.00000    0.0  0.0        1  120.000000
# ..   ...  ...              ...        ...    ...  ...      ...         ...
# 194   54    0                4  127.00000  333.0  1.0        1  154.000000
# 195   62    1                1  133.72028  139.0  0.0        1  122.869863
# 196   55    1                4  122.00000  223.0  1.0        1  100.000000
# 197   58    1                4  133.72028  385.0  1.0        2  122.869863
# 198   62    1                2  120.00000  254.0  0.0        2   93.000000
#
#         exang   oldpeak  num
# 0    0.000000  0.000000    0
# 1    1.000000  1.500000    2
# 2    1.000000  2.500000    1
# 3    1.000000  1.300000    0
# 4    0.000000 -0.500000    0
# ..        ...       ...  ...
# 194  0.000000  0.000000    1
# 195  0.643836  1.309091    0
# 196  0.000000  0.000000    2
# 197  0.643836  1.309091    0
# 198  1.000000  0.000000    1
#
# [199 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# age                0
# sex                0
# chest_pain_type    0
# trestbps           0
# chol               0
# fbs                0
# restecg            0
# thalach            0
# exang              0
# oldpeak            0
# num                0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.corr()
# Out:
#                       age       sex  chest_pain_type  trestbps      chol  \
# age              1.000000  0.033837        -0.039809  0.180915  0.065347
# sex              0.033837  1.000000         0.037525  0.012238 -0.096953
# chest_pain_type -0.039809  0.037525         1.000000  0.073888  0.063650
# trestbps         0.180915  0.012238         0.073888  1.000000  0.149121
# chol             0.065347 -0.096953         0.063650  0.149121  1.000000
# fbs              0.126706 -0.054735        -0.045135  0.186111  0.154537
# restecg          0.001487  0.060305         0.033617  0.091401  0.022824
# thalach         -0.148786 -0.001016        -0.122405 -0.012047 -0.039052
# exang            0.133318  0.015703         0.180299  0.219314  0.084179
# oldpeak          0.154215  0.096219         0.036454  0.113345 -0.005121
# num              0.286630  0.147190         0.167202  0.141186  0.075094
#
#                       fbs   restecg   thalach     exang   oldpeak       num
# age              0.126706  0.001487 -0.148786  0.133318  0.154215  0.286630
# sex             -0.054735  0.060305 -0.001016  0.015703  0.096219  0.147190
# chest_pain_type -0.045135  0.033617 -0.122405  0.180299  0.036454  0.167202
# trestbps         0.186111  0.091401 -0.012047  0.219314  0.113345  0.141186
# chol             0.154537  0.022824 -0.039052  0.084179 -0.005121  0.075094
# fbs              1.000000  0.167662  0.049509 -0.210867 -0.093830  0.052104
# restecg          0.167662  1.000000  0.013548 -0.082538 -0.111718 -0.033597
# thalach          0.049509  0.013548  1.000000 -0.072758  0.178435 -0.078186
# exang           -0.210867 -0.082538 -0.072758  1.000000  0.304988  0.254020
# oldpeak         -0.093830 -0.111718  0.178435  0.304988  1.000000  0.378550
# num              0.052104 -0.033597 -0.078186  0.254020  0.378550  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)

# %%
df.describe()
# Out:
#               age         sex  chest_pain_type   trestbps        chol  \
# count  199.000000  199.000000       199.000000  199.00000  199.000000
# mean    59.331658    0.969849         3.502513  133.72028  178.322917
# std      7.827080    0.171433         0.796928   18.29815  112.144792
# min     35.000000    0.000000         1.000000    0.00000    0.000000
# 25%     55.000000    1.000000         3.000000  125.50000  119.500000
# 50%     60.000000    1.000000         4.000000  133.72028  214.000000
# 75%     64.000000    1.000000         4.000000  140.00000  254.000000
# max     77.000000    1.000000         4.000000  190.00000  458.000000
#
#               fbs     restecg     thalach       exang     oldpeak         num
# count  199.000000  199.000000  199.000000  199.000000  199.000000  199.000000
# mean     0.354167    0.733668  122.869863    0.643836    1.309091    1.517588
# std      0.470958    0.684918   18.867497    0.411203    0.932462    1.222038
# min      0.000000    0.000000   69.000000    0.000000   -0.500000    0.000000
# 25%      0.000000    0.000000  112.000000    0.000000    1.000000    0.000000
# 50%      0.000000    1.000000  122.869863    0.643836    1.309091    1.000000
# 75%      1.000000    1.000000  130.000000    1.000000    2.000000    3.000000
# max      1.000000    2.000000  180.000000    1.000000    4.000000    4.000000

# %% [markdown]
# Observation
# 1)There may be outliers present in the Chol columns.
# 2)The min and max of thalch columns is also high.

# %%
df.plot(kind="box",subplots=True,layout=(5,5),figsize=(15,15))
# Out:
# age                   AxesSubplot(0.125,0.749828;0.133621x0.130172)
# sex                AxesSubplot(0.285345,0.749828;0.133621x0.130172)
# chest_pain_type     AxesSubplot(0.44569,0.749828;0.133621x0.130172)
# trestbps           AxesSubplot(0.606034,0.749828;0.133621x0.130172)
# chol               AxesSubplot(0.766379,0.749828;0.133621x0.130172)
# fbs                   AxesSubplot(0.125,0.593621;0.133621x0.130172)
# restecg            AxesSubplot(0.285345,0.593621;0.133621x0.130172)
# thalach             AxesSubplot(0.44569,0.593621;0.133621x0.130172)
# exang              AxesSubplot(0.606034,0.593621;0.133621x0.130172)
# oldpeak            AxesSubplot(0.766379,0.593621;0.133621x0.130172)
# num                   AxesSubplot(0.125,0.437414;0.133621x0.130172)
# dtype: object

# %% [markdown]
# As we can see there are outliers present in thalach and trestbps.

# %%
# check tpypes of diagnosis
df["num"].unique()
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %% [markdown]
# As per the problem description, 0 means no heart disease and 1-3 represent presence of heart disease

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              199 non-null    int64
#  1   sex              199 non-null    int64
#  2   chest_pain_type  199 non-null    int64
#  3   trestbps         199 non-null    float64
#  4   chol             199 non-null    float64
#  5   fbs              199 non-null    float64
#  6   restecg          199 non-null    int64
#  7   thalach          199 non-null    float64
#  8   exang            199 non-null    float64
#  9   oldpeak          199 non-null    float64
#  10  num              199 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 17.2 KB

# %%
df["chest_pain_type"].unique()
# Out:
# array([4, 3, 2, 1], dtype=int64)

# %%
df["chest_pain_type"]=df.chest_pain_type.astype(float)
df["restecg"]=df.restecg.astype(float)
df["sex"]=df.sex.astype(float)

# %%
sns.countplot(x="sex",data=df)

# %%
sns.countplot(x="num", data=df, palette="Dark2")

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['num'] = le.fit_transform(df['num'])
df.head(5)
# Out:
#    age  sex  chest_pain_type  trestbps   chol  fbs  restecg  thalach  exang  \
# 0   44    7              4.0     130.0  209.0  0.0      1.0    127.0    0.0
# 1   60   22              4.0     132.0  218.0  0.0      1.0    140.0    1.0
# 2   55   17              4.0     142.0  228.0  0.0      1.0    149.0    1.0
# 3   66   28              3.0     110.0  213.0  1.0      2.0     99.0    1.0
# 4   66   28              3.0     120.0    0.0  0.0      1.0    120.0    0.0
#
#    oldpeak  num
# 0      0.0    0
# 1      1.5    2
# 2      2.5    1
# 3      1.3    0
# 4     -0.5    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              199 non-null    int64
#  1   sex              199 non-null    int64
#  2   chest_pain_type  199 non-null    float64
#  3   trestbps         199 non-null    float64
#  4   chol             199 non-null    float64
#  5   fbs              199 non-null    float64
#  6   restecg          199 non-null    float64
#  7   thalach          199 non-null    float64
#  8   exang            199 non-null    float64
#  9   oldpeak          199 non-null    float64
#  10  num              199 non-null    int64
# dtypes: float64(8), int64(3)
# memory usage: 17.2 KB

# %%
sns.boxplot(x=df['sex'],y=df['num'])

# %%
#checking skweness
df.skew()
# Out:
# age               -0.397178
# sex               -0.329402
# chest_pain_type   -1.641267
# trestbps          -1.501953
# chol              -0.563256
# fbs                0.625593
# restecg            0.396540
# thalach            0.137597
# exang             -0.706686
# oldpeak            0.441233
# num                0.302681
# dtype: float64

# %%
#spliting the data

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x=df.iloc[:,0:-1]
x
# Out:
#      age  sex  chest_pain_type   trestbps   chol  fbs  restecg     thalach  \
# 0     44    7              4.0  130.00000  209.0  0.0      1.0  127.000000
# 1     60   22              4.0  132.00000  218.0  0.0      1.0  140.000000
# 2     55   17              4.0  142.00000  228.0  0.0      1.0  149.000000
# 3     66   28              3.0  110.00000  213.0  1.0      2.0   99.000000
# 4     66   28              3.0  120.00000    0.0  0.0      1.0  120.000000
# ..   ...  ...              ...        ...    ...  ...      ...         ...
# 194   54   16              4.0  127.00000  333.0  1.0      1.0  154.000000
# 195   62   24              1.0  133.72028  139.0  0.0      1.0  122.869863
# 196   55   17              4.0  122.00000  223.0  1.0      1.0  100.000000
# 197   58   20              4.0  133.72028  385.0  1.0      2.0  122.869863
# 198   62   24              2.0  120.00000  254.0  0.0      2.0   93.000000
#
#         exang   oldpeak
# 0    0.000000  0.000000
# 1    1.000000  1.500000
# 2    1.000000  2.500000
# 3    1.000000  1.300000
# 4    0.000000 -0.500000
# ..        ...       ...
# 194  0.000000  0.000000
# 195  0.643836  1.309091
# 196  0.000000  0.000000
# 197  0.643836  1.309091
# 198  1.000000  0.000000
#
# [199 rows x 10 columns]

# %%
y=df["num"]
y
# Out:
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
#       ..
# 194    1
# 195    0
# 196    2
# 197    0
# 198    1
# Name: num, Length: 199, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33, random_state=44)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
lr=LogisticRegression()
dtc=DecisionTreeClassifier()
knc=KNeighborsClassifier()
rf=RandomForestClassifier()
svc=SVC()

# %%
models=[]
models.append(("LogisticRegression",lr))
models.append(("DecisionTreeCLasifier",dtc))
models.append(("KNeighborsClassifier",knc))
models.append(("RandomForestClassifier",rf))
models.append(("SVC",svc))

# %%
Model=[]
confusionmatrix=[]
Accuracyscore=[]
cr=[]
ae=[]
MSE=[]
rms=[]
for name, model in models:
    print(name)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    model.score(x_train, y_train)
    print(accuracy_score(y_test, pre))
    Accuracyscore.append(accuracy_score(y_test,pre))
    print(confusion_matrix(y_test, pre))
    confusionmatrix.append(confusion_matrix(y_test, pre))
    print(classification_report(y_test, pre))
    cr.append(classification_report(y_test, pre))
    print('Mean absolute error:', mean_absolute_error(y_test, pre))
    ae.append((mean_absolute_error(y_test, pre)))
    print('Mean squared error:', mean_squared_error(y_test, pre))
    MSE.append((mean_squared_error(y_test, pre)))
    print("\n")
# Out:
# LogisticRegression
# 0.3333333333333333
# [[ 5  9  0  2  1]
#  [ 4 10  0  3  1]
#  [ 3  5  0 10  0]
#  [ 2  2  0  7  0]
#  [ 0  1  0  1  0]]
#               precision    recall  f1-score   support
#
#            0       0.36      0.29      0.32        17
#            1       0.37      0.56      0.44        18
#            2       0.00      0.00      0.00        18
#            3       0.30      0.64      0.41        11
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.33        66
#    macro avg       0.21      0.30      0.24        66
# weighted avg       0.24      0.33      0.27        66
#
# Mean absolute error: 1.0151515151515151
# Mean squared error: 1.9848484848484849
#
#
# DecisionTreeCLasifier
# 0.36363636363636365
# [[9 4 1 1 2]
#  [4 7 1 5 1]
#  [1 5 6 3 3]
#  [3 2 2 2 2]
#  [0 1 1 0 0]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.53      0.53        17
#            1       0.37      0.39      0.38        18
#            2       0.55      0.33      0.41        18
#            3       0.18      0.18      0.18        11
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.36        66
#    macro avg       0.33      0.29      0.30        66
# weighted avg       0.42      0.36      0.38        66
#
# Mean absolute error: 1.106060606060606
# Mean squared error: 2.409090909090909
#
#
# KNeighborsClassifier
# 0.2727272727272727
# [[10  5  0  2  0]
#  [11  2  2  3  0]
#  [ 5  7  2  4  0]
#  [ 2  3  2  4  0]
#  [ 1  1  0  0  0]]
#               precision    recall  f1-score   support
#
#            0       0.34      0.59      0.43        17
#            1       0.11      0.11      0.11        18
#            2       0.33      0.11      0.17        18
#            3       0.31      0.36      0.33        11
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.27        66
#    macro avg       0.22      0.23      0.21        66
# weighted avg       0.26      0.27      0.24        66
#
# Mean absolute error: 1.0909090909090908
# Mean squared error: 2.0606060606060606
#
#
# RandomForestClassifier
# 0.36363636363636365
# [[7 6 2 2 0]
#  [5 7 2 4 0]
#  [3 1 5 7 2]
#  [3 3 0 5 0]
#  [1 1 0 0 0]]
#               precision    recall  f1-score   support
#
#            0       0.37      0.41      0.39        17
#            1       0.39      0.39      0.39        18
#            2       0.56      0.28      0.37        18
#            3       0.28      0.45      0.34        11
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.36        66
#    macro avg       0.32      0.31      0.30        66
# weighted avg       0.40      0.36      0.36        66
#
# Mean absolute error: 1.0757575757575757
# Mean squared error: 2.227272727272727
#
#
# SVC
# 0.25757575757575757
# [[ 0 13  0  4  0]
#  [ 0 15  0  3  0]
#  [ 0 15  0  3  0]
#  [ 0  9  0  2  0]
#  [ 0  2  0  0  0]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        17
#            1       0.28      0.83      0.42        18
#            2       0.00      0.00      0.00        18
#            3       0.17      0.18      0.17        11
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.26        66
#    macro avg       0.09      0.20      0.12        66
# weighted avg       0.10      0.26      0.14        66
#
# Mean absolute error: 1.106060606060606
# Mean squared error: 2.015151515151515

# %% [markdown]
# From the observation logistic regression is working well.

# %%
import pickle
filename = 'heartdisease.pkl'
pickle.dump(lr, open(filename, 'wb'))
